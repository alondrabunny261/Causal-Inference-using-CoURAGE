# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

# %%
cd
# Out:
# /Users/alondraalvarez

# %%
cd Desktop/"REU 2025"
# Out:
# /Users/alondraalvarez/Desktop/REU 2025

# %%
# Limpieza columnas
for col in ["Precipitation on Temperature interval 1", "Precipitation on Temperature interval 2", "Precipitation on Temperature"]:
    if df_urban[col].dtype == "object":
        df_urban[col] = df_urban[col].str.strip("[]").astype(float)
    else:
        df_urban[col] = df_urban[col].astype(float)

coef = df_urban["Precipitation on Temperature"]
ci_lower = df_urban["Precipitation on Temperature interval 1"]
ci_upper = df_urban["Precipitation on Temperature interval 2"]

coef_arr = coef.to_numpy()
ci_lower_arr = ci_lower.to_numpy()
ci_upper_arr = ci_upper.to_numpy()

# Promedio elemento a elemento
promedio_entre_medio = np.median((coef_arr + ci_lower_arr + ci_upper_arr) / 3)
print(promedio_entre_medio)

plt.figure(figsize=(10, 6))
sns.kdeplot(coef, fill=True, color='orchid', label='Average Distribution of estimates')
sns.kdeplot(ci_lower, fill=True, color='skyblue', label='Upper Confidence Interval')
sns.kdeplot(ci_upper, fill=True, color='purple', label='Lower Confidence Interval')
#sns.kdeplot(promedio_entre_medio, fill=True, color='green', label='Promedio entre medio')

plt.axvline(data.mean(), color='red', linestyle='--', label=f'Median = {promedio_entre_medio}')
plt.axvline(0, color='gray', linestyle=':')

plt.title(f"{site}:Distribution of Wright's Causal Estimation of Specific Humidity-->Aerosols", fontsize=18)
plt.xlabel("Wright's Causal Estimation", fontsize=15)
plt.ylabel("Density", fontsize=15)
plt.legend()
plt.tight_layout()
plt.show()
# Out:
# -0.008203238333333333
# /opt/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
site="Rural"

# %%
# Limpieza columnas
for col in ["CO2 on Temperature interval 1", "CO2 on Temperature interval 2", "CO2 on Temperature"]:
    if df_rural[col].dtype == "object":
        df_rural[col] = df_rural[col].str.strip("[]").astype(float)
    else:
        df_rural[col] = df_rural[col].astype(float)

coef = df_rural["CO2 on Temperature"]
ci_lower = df_rural["CO2 on Temperature interval 1"]
ci_upper = df_rural["CO2 on Temperature interval 2"]

coef_arr = coef.to_numpy()
ci_lower_arr = ci_lower.to_numpy()
ci_upper_arr = ci_upper.to_numpy()

# Promedio elemento a elemento
promedio_entre_medio = np.median((coef_arr + ci_lower_arr + ci_upper_arr) / 3)
print(promedio_entre_medio)

plt.figure(figsize=(9, 6))
sns.kdeplot(coef, fill=True, color='orchid', label='Average Distribution of estimates')
sns.kdeplot(ci_lower, fill=True, color='skyblue', label='Lower Confidence Interval')
sns.kdeplot(ci_upper, fill=True, color='purple', label='Upper Confidence Interval')
#sns.kdeplot(promedio_entre_medio, fill=True, color='green', label='Promedio entre medio')

plt.axvline(promedio_entre_medio, color='red', linestyle='--', label=f'Median = {promedio_entre_medio}')
plt.axvline(0, color='gray', linestyle=':')

plt.title(f"{site}:Night Distribution of Wright's Causal Estimation of CO2-->Temperature", fontsize=18)
plt.xlabel("Wright's Causal Estimation", fontsize=15)
plt.ylabel("Event Frequency", fontsize=15)
plt.legend()
plt.tight_layout()
plt.show()
# Out:
# -3.69142327
# /opt/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
site="Bay"

# %%
# Limpieza columnas
for col in ["Precipitation on Temperature interval 1", "Precipitation on Temperature interval 2", "Precipitation on Temperature"]:
    if df_bay[col].dtype == "object":
        df_bay[col] = df_bay[col].str.strip("[]").astype(float)
    else:
        df_bay[col] = df_bay[col].astype(float)

coef = df_bay["Precipitation on Temperature"]
ci_lower = df_bay["Precipitation on Temperature interval 1"]
ci_upper = df_bay["Precipitation on Temperature interval 2"]

coef_arr = coef.to_numpy()
ci_lower_arr = ci_lower.to_numpy()
ci_upper_arr = ci_upper.to_numpy()

# Promedio elemento a elemento
promedio_entre_medio = np.median((coef_arr + ci_lower_arr + ci_upper_arr) / 3)
print(promedio_entre_medio)

plt.figure(figsize=(10, 6))
sns.kdeplot(coef, fill=True, color='orchid', label='Average Distribution of estimates')
sns.kdeplot(ci_lower, fill=True, color='skyblue', label='Upper Confidence Interval')
sns.kdeplot(ci_upper, fill=True, color='purple', label='Lower Confidence Interval')
#sns.kdeplot(promedio_entre_medio, fill=True, color='green', label='Promedio entre medio')

plt.axvline(promedio_entre_medio, color='red', linestyle='--', label=f'Median = {promedio_entre_medio}')
plt.axvline(0, color='gray', linestyle=':')

plt.title(f"{site}:Distribution of Wright's Causal Estimation of Specific Humidity-->Aerosols", fontsize=18)
plt.xlabel("Wright's Causal Estimation", fontsize=15)
plt.ylabel("Density", fontsize=15)
plt.legend()
plt.tight_layout()
plt.show()
# Out:
# -0.007112833333333333
# /opt/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
from graphviz import Digraph

dot = Digraph()
dot.edge('A', 'B')
dot.edge('B', 'C')
dot.edge('A', 'C')

dot.render('dag_example', view=True)
# Out:
# 'dag_example.pdf'

# %%
import networkx as nx
import matplotlib.pyplot as plt

G = nx.DiGraph()  # DiGraph = Directed Graph

# Agregar nodos y aristas
G.add_edges_from([("A", "B"), ("B", "C"), ("A", "C")])

# Verificar si es acíclico
print("Es DAG:", nx.is_directed_acyclic_graph(G))

# Dibujar
nx.draw(G, with_labels=True, node_color='lightblue', arrows=True)
plt.show()

nx.draw(node)
# Out:
# Es DAG: True

# %%
from graphviz import Digraph

dot = Digraph()
dot.edge('CO2', 'Temperature')
dot.edge('Aerosols', 'Temperature')
dot.edge('Specific Humidity', 'Temperature')
dot.edge('Specific Humidity', 'Aerosols')

# Forzar que B y C estén al mismo nivel
with dot.subgraph() as s:
    s.attr(rank='same')
    s.node('CO2')
    s.node('Aerosols')
    s.node('Specific Humidity')
    
dot  # Esto lo mostrará directamente en el notebook
